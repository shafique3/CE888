# %% [markdown]
# # Agrotech Preprocess

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Read plant data from excel file

# %%
plants = pd.read_excel ('Data.xlsx','plants',parse_dates=True)

# %%
plants.head()
# Out:
#    Batch Number Plant Date  Class  Fresh Weight (g)  Head Weight (g)  \
# 0           402 2020-04-11      3              15.0              NaN
# 1           402 2020-04-11      4              15.0              NaN
# 2           402 2020-04-11      1              16.0              NaN
# 3           402 2020-04-11      3              15.0              NaN
# 4           402 2020-04-11      3              15.0              NaN
#
#    Radial Diameter (mm)  Polar Diameter (mm)  Diameter Ratio  Leaves  \
# 0                   NaN                  NaN             NaN    10.0
# 1                   NaN                  NaN             NaN    11.0
# 2                   NaN                  NaN             NaN    12.0
# 3                   NaN                  NaN             NaN    10.0
# 4                   NaN                  NaN             NaN    11.0
#
#    Density (kg/L)  Leaf Area (cm^2)  Square ID Check Date Flight Date Remove
# 0             NaN             185.0        208 2020-04-30         NaT    NaN
# 1             NaN             156.0        208 2020-04-30         NaT    NaN
# 2             NaN             137.0        208 2020-04-30         NaT    NaN
# 3             NaN             225.0        208 2020-04-30         NaT    NaN
# 4             NaN             157.0        208 2020-04-30         NaT    NaN

# %% [markdown]
# # To read the flight dates data

# %%
flight_dates=pd.read_excel('Data.xlsx','flight dates',parse_dates=True)

# %%
flight_dates.tail()
# Out:
#     Batch Number Flight Date
# 45           651  2020-08-27
# 46           689  2020-09-09
# 47           690  2020-09-09
# 48           691  2020-09-10
# 49           693  2020-09-10

# %% [markdown]
# # To read the planting sheet data

# %%
planting=pd.read_excel('Data.xlsx','planting',parse_dates=True)

# %%
planting.head()
# Out:
#    Crop  Column2  Column3 Plant_Date  Column1  Region  Column4  \
# 0     3      NaN      NaN 2020-02-06      NaN       0      NaN
# 1     3      NaN      NaN 2020-02-07      NaN       0      NaN
# 2     3      NaN      NaN 2020-02-07      NaN       0      NaN
# 3     3      NaN      NaN 2020-02-08      NaN       0      NaN
# 4     3      NaN      NaN 2020-02-10      NaN       0      NaN
#
#    Planting_Batch  Volume_Planted  Planting_Wk
# 0             392          198912            6
# 1             503           63840            6
# 2             614          179928            6
# 3             725          200256            6
# 4             770           13944            7

# %% [markdown]
# # To read the weather data

# %%
weather=pd.read_excel('Data.xlsx','weather')

# %%
weather.tail()
# Out:
#      Unnamed: 0  Solar Radiation [avg]  Precipitation [sum]  Wind Speed [avg]  \
# 2551 2021-05-17                    196                  1.4               2.2
# 2552 2021-05-17                    173                  2.8               1.8
# 2553 2021-05-18                    311                  0.0               1.4
# 2554 2021-05-19                    232                  6.6               1.8
# 2555 2021-05-20                     44                  0.0               0.5
#
#       Wind Speed [max]  Battery Voltage [last]  Leaf Wetness [time]  \
# 2551               5.5                    7166                    0
# 2552               5.5                    6864                    0
# 2553               5.0                    6854                    0
# 2554               5.5                    6864                    0
# 2555               2.7                    7158                    0
#
#       Air Temperature [avg]  Air Temperature [max]  Air Temperature [min]  \
# 2551                  10.51                  14.53                   8.95
# 2552                  10.80                  14.53                   8.38
# 2553                  10.29                  17.14                   3.15
# 2554                  11.39                  16.61                   7.50
# 2555                   6.35                   9.15                   3.76
#
#       Relative Humidity [avg]  Dew Point [avg]  Dew Point [min]  ET0 [result]
# 2551                    99.86             10.3              8.8           NaN
# 2552                    99.86             10.6              8.2           NaN
# 2553                    92.94              8.8              3.0           3.4
# 2554                    90.32              9.4              5.2           3.0
# 2555                    99.86              6.2              3.6           NaN

# %% [markdown]
# # To check the null values in the plant data

# %%
print("Number of null values in each column of plants data")
print(plants.isnull().sum())
# Out:
# Number of null values in each column of plants data
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           1
# Head Weight (g)          105
# Radial Diameter (mm)     105
# Polar Diameter (mm)      105
# Diameter Ratio           107
# Leaves                  4759
# Density (kg/L)           187
# Leaf Area (cm^2)           2
# Square ID                  0
# Check Date                 0
# Flight Date             4387
# Remove                  4789
# dtype: int64

# %% [markdown]
# # To check the null values in planting data

# %%
print("Number of null values in each column of planting data")
print(planting.isnull().sum())
# Out:
# Number of null values in each column of planting data
# Crop                 0
# Column2           1821
# Column3           1821
# Plant_Date           0
# Column1           1821
# Region               0
# Column4           1821
# Planting_Batch       0
# Volume_Planted       0
# Planting_Wk          0
# dtype: int64

# %% [markdown]
# # To check the null values in the flight dates data

# %%
print("Number of null values in each column of flight_dates data")
print(flight_dates.isnull().sum())
# Out:
# Number of null values in each column of flight_dates data
# Batch Number    0
# Flight Date     0
# dtype: int64

# %% [markdown]
# # To check the null values in the weather data

# %%
print("Number of null values in each column of weather data")
print(weather.isnull().sum())
# Out:
# Number of null values in each column of weather data
# Unnamed: 0                  0
# Solar Radiation [avg]       0
# Precipitation [sum]         0
# Wind Speed [avg]            0
# Wind Speed [max]            0
# Battery Voltage [last]      0
# Leaf Wetness [time]         0
# Air Temperature [avg]       0
# Air Temperature [max]       0
# Air Temperature [min]       0
# Relative Humidity [avg]     0
# Dew Point [avg]             3
# Dew Point [min]            46
# ET0 [result]               66
# dtype: int64

# %% [markdown]
# # To drop the empty columns in the planting data

# %%
planting=planting.drop(['Column2'],axis=1)

# %%
planting.head()
# Out:
#    Crop  Column3 Plant_Date  Column1  Region  Column4  Planting_Batch  \
# 0     3      NaN 2020-02-06      NaN       0      NaN             392
# 1     3      NaN 2020-02-07      NaN       0      NaN             503
# 2     3      NaN 2020-02-07      NaN       0      NaN             614
# 3     3      NaN 2020-02-08      NaN       0      NaN             725
# 4     3      NaN 2020-02-10      NaN       0      NaN             770
#
#    Volume_Planted  Planting_Wk
# 0          198912            6
# 1           63840            6
# 2          179928            6
# 3          200256            6
# 4           13944            7

# %%
planting=planting.drop(['Column3','Column1','Column4'],axis=1)

# %%
planting.head()
# Out:
#    Crop Plant_Date  Region  Planting_Batch  Volume_Planted  Planting_Wk
# 0     3 2020-02-06       0             392          198912            6
# 1     3 2020-02-07       0             503           63840            6
# 2     3 2020-02-07       0             614          179928            6
# 3     3 2020-02-08       0             725          200256            6
# 4     3 2020-02-10       0             770           13944            7

# %% [markdown]
# # Check the missing values in the planting data

# %%
print(planting.isnull().sum())
# Out:
# Crop              0
# Plant_Date        0
# Region            0
# Planting_Batch    0
# Volume_Planted    0
# Planting_Wk       0
# dtype: int64

# %% [markdown]
# # Checking the tail of entries of the plant data

# %%
plants.tail()
# Out:
#       Batch Number Plant Date  Class  Fresh Weight (g)  Head Weight (g)  \
# 4854           738 2020-08-27      4             284.0             12.0
# 4855           738 2020-08-27      5             199.0              8.0
# 4856           738 2020-08-27      3             280.0             23.0
# 4857           738 2020-08-27      4             247.0             10.0
# 4858           738 2020-08-27      2             183.0             18.0
#
#       Radial Diameter (mm)  Polar Diameter (mm)  Diameter Ratio  Leaves  \
# 4854                  50.0                 55.0        0.909091     NaN
# 4855                  45.0                 85.0        0.529412     NaN
# 4856                  60.0                 80.0        0.750000     NaN
# 4857                  45.0                 80.0        0.562500     NaN
# 4858                  35.0                102.0        0.343137     NaN
#
#       Density (kg/L)  Leaf Area (cm^2)  Square ID Check Date Flight Date  \
# 4854             NaN             430.0       1172 2020-10-20         NaT
# 4855             NaN             358.0       1172 2020-10-20         NaT
# 4856             NaN             417.0       1172 2020-10-20         NaT
# 4857             NaN             413.0       1172 2020-10-20         NaT
# 4858             NaN             316.0       1172 2020-10-20         NaT
#
#      Remove
# 4854    NaN
# 4855    NaN
# 4856    NaN
# 4857    NaN
# 4858    NaN

# %% [markdown]
# # Removing the r values rows from the plant data

# %%
plants.drop(plants[plants.Remove == 'r'].index, inplace=True)

# %%
plants.tail()
# Out:
#       Batch Number Plant Date  Class  Fresh Weight (g)  Head Weight (g)  \
# 4854           738 2020-08-27      4             284.0             12.0
# 4855           738 2020-08-27      5             199.0              8.0
# 4856           738 2020-08-27      3             280.0             23.0
# 4857           738 2020-08-27      4             247.0             10.0
# 4858           738 2020-08-27      2             183.0             18.0
#
#       Radial Diameter (mm)  Polar Diameter (mm)  Diameter Ratio  Leaves  \
# 4854                  50.0                 55.0        0.909091     NaN
# 4855                  45.0                 85.0        0.529412     NaN
# 4856                  60.0                 80.0        0.750000     NaN
# 4857                  45.0                 80.0        0.562500     NaN
# 4858                  35.0                102.0        0.343137     NaN
#
#       Density (kg/L)  Leaf Area (cm^2)  Square ID Check Date Flight Date  \
# 4854             NaN             430.0       1172 2020-10-20         NaT
# 4855             NaN             358.0       1172 2020-10-20         NaT
# 4856             NaN             417.0       1172 2020-10-20         NaT
# 4857             NaN             413.0       1172 2020-10-20         NaT
# 4858             NaN             316.0       1172 2020-10-20         NaT
#
#      Remove
# 4854    NaN
# 4855    NaN
# 4856    NaN
# 4857    NaN
# 4858    NaN

# %%
plants.shape
# Out:
# (4789, 15)

# %%
plants=plants.reset_index()

# %%
plants.tail()
# Out:
#       index  Batch Number Plant Date  Class  Fresh Weight (g)  \
# 4784   4854           738 2020-08-27      4             284.0
# 4785   4855           738 2020-08-27      5             199.0
# 4786   4856           738 2020-08-27      3             280.0
# 4787   4857           738 2020-08-27      4             247.0
# 4788   4858           738 2020-08-27      2             183.0
#
#       Head Weight (g)  Radial Diameter (mm)  Polar Diameter (mm)  \
# 4784             12.0                  50.0                 55.0
# 4785              8.0                  45.0                 85.0
# 4786             23.0                  60.0                 80.0
# 4787             10.0                  45.0                 80.0
# 4788             18.0                  35.0                102.0
#
#       Diameter Ratio  Leaves  Density (kg/L)  Leaf Area (cm^2)  Square ID  \
# 4784        0.909091     NaN             NaN             430.0       1172
# 4785        0.529412     NaN             NaN             358.0       1172
# 4786        0.750000     NaN             NaN             417.0       1172
# 4787        0.562500     NaN             NaN             413.0       1172
# 4788        0.343137     NaN             NaN             316.0       1172
#
#      Check Date Flight Date Remove
# 4784 2020-10-20         NaT    NaN
# 4785 2020-10-20         NaT    NaN
# 4786 2020-10-20         NaT    NaN
# 4787 2020-10-20         NaT    NaN
# 4788 2020-10-20         NaT    NaN

# %%
print("Number of null values in each column of plants data")
print(plants.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                      0
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           1
# Head Weight (g)          105
# Radial Diameter (mm)     105
# Polar Diameter (mm)      105
# Diameter Ratio           107
# Leaves                  4689
# Density (kg/L)           187
# Leaf Area (cm^2)           2
# Square ID                  0
# Check Date                 0
# Flight Date             4321
# Remove                  4789
# dtype: int64

# %% [markdown]
# # Removing the Remove column from the plant data

# %%
plants=plants.drop(['Remove'],axis=1)

# %%
plants.tail()
# Out:
#       index  Batch Number Plant Date  Class  Fresh Weight (g)  \
# 4784   4854           738 2020-08-27      4             284.0
# 4785   4855           738 2020-08-27      5             199.0
# 4786   4856           738 2020-08-27      3             280.0
# 4787   4857           738 2020-08-27      4             247.0
# 4788   4858           738 2020-08-27      2             183.0
#
#       Head Weight (g)  Radial Diameter (mm)  Polar Diameter (mm)  \
# 4784             12.0                  50.0                 55.0
# 4785              8.0                  45.0                 85.0
# 4786             23.0                  60.0                 80.0
# 4787             10.0                  45.0                 80.0
# 4788             18.0                  35.0                102.0
#
#       Diameter Ratio  Leaves  Density (kg/L)  Leaf Area (cm^2)  Square ID  \
# 4784        0.909091     NaN             NaN             430.0       1172
# 4785        0.529412     NaN             NaN             358.0       1172
# 4786        0.750000     NaN             NaN             417.0       1172
# 4787        0.562500     NaN             NaN             413.0       1172
# 4788        0.343137     NaN             NaN             316.0       1172
#
#      Check Date Flight Date
# 4784 2020-10-20         NaT
# 4785 2020-10-20         NaT
# 4786 2020-10-20         NaT
# 4787 2020-10-20         NaT
# 4788 2020-10-20         NaT

# %%
print("Number of null values in each column of plants data")
print(plants.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                      0
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           1
# Head Weight (g)          105
# Radial Diameter (mm)     105
# Polar Diameter (mm)      105
# Diameter Ratio           107
# Leaves                  4689
# Density (kg/L)           187
# Leaf Area (cm^2)           2
# Square ID                  0
# Check Date                 0
# Flight Date             4321
# dtype: int64

# %%
plants.shape
# Out:
# (4789, 15)

# %%
plants.head()
# Out:
#    index  Batch Number Plant Date  Class  Fresh Weight (g)  Head Weight (g)  \
# 0      0           402 2020-04-11      3              15.0              NaN
# 1      1           402 2020-04-11      4              15.0              NaN
# 2      2           402 2020-04-11      1              16.0              NaN
# 3      3           402 2020-04-11      3              15.0              NaN
# 4      4           402 2020-04-11      3              15.0              NaN
#
#    Radial Diameter (mm)  Polar Diameter (mm)  Diameter Ratio  Leaves  \
# 0                   NaN                  NaN             NaN    10.0
# 1                   NaN                  NaN             NaN    11.0
# 2                   NaN                  NaN             NaN    12.0
# 3                   NaN                  NaN             NaN    10.0
# 4                   NaN                  NaN             NaN    11.0
#
#    Density (kg/L)  Leaf Area (cm^2)  Square ID Check Date Flight Date
# 0             NaN             185.0        208 2020-04-30         NaT
# 1             NaN             156.0        208 2020-04-30         NaT
# 2             NaN             137.0        208 2020-04-30         NaT
# 3             NaN             225.0        208 2020-04-30         NaT
# 4             NaN             157.0        208 2020-04-30         NaT

# %% [markdown]
# # Droping the Diameter ratio column from the plant data

# %%
plants=plants.drop(['Diameter Ratio'],axis=1)

# %%
print("Number of null values in each column of plants data")
print(plants.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                      0
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           1
# Head Weight (g)          105
# Radial Diameter (mm)     105
# Polar Diameter (mm)      105
# Leaves                  4689
# Density (kg/L)           187
# Leaf Area (cm^2)           2
# Square ID                  0
# Check Date                 0
# Flight Date             4321
# dtype: int64

# %% [markdown]
# # Drop the density colmn from the plant data

# %%
plants=plants.drop(['Density (kg/L)'],axis=1)

# %%
print("Number of null values in each column of plants data")
print(plants.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                      0
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           1
# Head Weight (g)          105
# Radial Diameter (mm)     105
# Polar Diameter (mm)      105
# Leaves                  4689
# Leaf Area (cm^2)           2
# Square ID                  0
# Check Date                 0
# Flight Date             4321
# dtype: int64

# %% [markdown]
# # Droping the head weight colmn from the plants data

# %%
plants=plants.drop(['Head Weight (g)'],axis=1)

# %%
print("Number of null values in each column of plants data")
print(plants.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                      0
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           1
# Radial Diameter (mm)     105
# Polar Diameter (mm)      105
# Leaves                  4689
# Leaf Area (cm^2)           2
# Square ID                  0
# Check Date                 0
# Flight Date             4321
# dtype: int64

# %% [markdown]
# # Merging the Flight date values from the floght data into plant data

# %%
merged_data=plants.merge(right=flight_dates,on='Batch Number',how='left')

# %%
print("Number of null values in each column of plants data")
print(plants.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                      0
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           1
# Radial Diameter (mm)     105
# Polar Diameter (mm)      105
# Leaves                  4689
# Leaf Area (cm^2)           2
# Square ID                  0
# Check Date                 0
# Flight Date             4321
# dtype: int64

# %%
plants.tail()
# Out:
#       index  Batch Number Plant Date  Class  Fresh Weight (g)  \
# 4784   4854           738 2020-08-27      4             284.0
# 4785   4855           738 2020-08-27      5             199.0
# 4786   4856           738 2020-08-27      3             280.0
# 4787   4857           738 2020-08-27      4             247.0
# 4788   4858           738 2020-08-27      2             183.0
#
#       Radial Diameter (mm)  Polar Diameter (mm)  Leaves  Leaf Area (cm^2)  \
# 4784                  50.0                 55.0     NaN             430.0
# 4785                  45.0                 85.0     NaN             358.0
# 4786                  60.0                 80.0     NaN             417.0
# 4787                  45.0                 80.0     NaN             413.0
# 4788                  35.0                102.0     NaN             316.0
#
#       Square ID Check Date Flight Date
# 4784       1172 2020-10-20         NaT
# 4785       1172 2020-10-20         NaT
# 4786       1172 2020-10-20         NaT
# 4787       1172 2020-10-20         NaT
# 4788       1172 2020-10-20         NaT

# %%
plants=plants.drop(['Flight Date'],axis=1)

# %%
plants.head()
# Out:
#    index  Batch Number Plant Date  Class  Fresh Weight (g)  \
# 0      0           402 2020-04-11      3              15.0
# 1      1           402 2020-04-11      4              15.0
# 2      2           402 2020-04-11      1              16.0
# 3      3           402 2020-04-11      3              15.0
# 4      4           402 2020-04-11      3              15.0
#
#    Radial Diameter (mm)  Polar Diameter (mm)  Leaves  Leaf Area (cm^2)  \
# 0                   NaN                  NaN    10.0             185.0
# 1                   NaN                  NaN    11.0             156.0
# 2                   NaN                  NaN    12.0             137.0
# 3                   NaN                  NaN    10.0             225.0
# 4                   NaN                  NaN    11.0             157.0
#
#    Square ID Check Date
# 0        208 2020-04-30
# 1        208 2020-04-30
# 2        208 2020-04-30
# 3        208 2020-04-30
# 4        208 2020-04-30

# %%
plants_flightdate=plants.merge(flight_dates,how='inner',on='Batch Number')

# %%
print("Number of null values in each column of plants data")
print(plants_flightdate.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                      0
# Batch Number               0
# Plant Date                40
# Class                      0
# Fresh Weight (g)           1
# Radial Diameter (mm)      98
# Polar Diameter (mm)       98
# Leaves                  3239
# Leaf Area (cm^2)           1
# Square ID                  0
# Check Date                 0
# Flight Date                0
# dtype: int64

# %%
plants_flightdate.head()
# Out:
#    index  Batch Number Plant Date  Class  Fresh Weight (g)  \
# 0      0           402 2020-04-11      3              15.0
# 1      1           402 2020-04-11      4              15.0
# 2      2           402 2020-04-11      1              16.0
# 3      3           402 2020-04-11      3              15.0
# 4      4           402 2020-04-11      3              15.0
#
#    Radial Diameter (mm)  Polar Diameter (mm)  Leaves  Leaf Area (cm^2)  \
# 0                   NaN                  NaN    10.0             185.0
# 1                   NaN                  NaN    11.0             156.0
# 2                   NaN                  NaN    12.0             137.0
# 3                   NaN                  NaN    10.0             225.0
# 4                   NaN                  NaN    11.0             157.0
#
#    Square ID Check Date Flight Date
# 0        208 2020-04-30  2020-04-30
# 1        208 2020-04-30  2020-04-30
# 2        208 2020-04-30  2020-04-30
# 3        208 2020-04-30  2020-04-30
# 4        208 2020-04-30  2020-04-30

# %%
plants_flightdate.shape
# Out:
# (3334, 12)

# %% [markdown]
# # Droping the leaves values from the plant data

# %%
plants_flightdate=plants_flightdate.drop(['Leaves'],axis=1)

# %%
print("Number of null values in each column of plants data")
print(plants_flightdate.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                    0
# Batch Number             0
# Plant Date              40
# Class                    0
# Fresh Weight (g)         1
# Radial Diameter (mm)    98
# Polar Diameter (mm)     98
# Leaf Area (cm^2)         1
# Square ID                0
# Check Date               0
# Flight Date              0
# dtype: int64

# %%
weather.head()
# Out:
#   Unnamed: 0  Solar Radiation [avg]  Precipitation [sum]  Wind Speed [avg]  \
# 0 2014-05-14                    159                  0.0               1.4
# 1 2014-05-15                    280                  0.0               0.6
# 2 2014-05-16                    186                  3.4               0.8
# 3 2014-05-17                    221                  0.0               1.0
# 4 2014-05-18                    255                  0.0               2.1
#
#    Wind Speed [max]  Battery Voltage [last]  Leaf Wetness [time]  \
# 0               3.3                    6834                   70
# 1               2.3                    6894                  500
# 2               2.7                    6874                  375
# 3               3.3                    6874                  565
# 4               5.5                    6854                  625
#
#    Air Temperature [avg]  Air Temperature [max]  Air Temperature [min]  \
# 0                  14.27                  18.90                   7.19
# 1                  13.51                  22.06                   3.04
# 2                  15.65                  24.24                   7.23
# 3                  17.46                  25.70                   9.93
# 4                  16.85                  24.62                   8.45
#
#    Relative Humidity [avg]  Dew Point [avg]  Dew Point [min]  ET0 [result]
# 0                    64.95              7.0              5.6           NaN
# 1                    72.91              7.6              3.0           3.6
# 2                    74.69             10.5              6.5           2.9
# 3                    71.42             11.5              8.1           3.6
# 4                    74.45             11.4              8.3           4.2

# %%
weather.shape
# Out:
# (2556, 14)

# %%
weather.tail()
# Out:
#      Unnamed: 0  Solar Radiation [avg]  Precipitation [sum]  Wind Speed [avg]  \
# 2551 2021-05-17                    196                  1.4               2.2
# 2552 2021-05-17                    173                  2.8               1.8
# 2553 2021-05-18                    311                  0.0               1.4
# 2554 2021-05-19                    232                  6.6               1.8
# 2555 2021-05-20                     44                  0.0               0.5
#
#       Wind Speed [max]  Battery Voltage [last]  Leaf Wetness [time]  \
# 2551               5.5                    7166                    0
# 2552               5.5                    6864                    0
# 2553               5.0                    6854                    0
# 2554               5.5                    6864                    0
# 2555               2.7                    7158                    0
#
#       Air Temperature [avg]  Air Temperature [max]  Air Temperature [min]  \
# 2551                  10.51                  14.53                   8.95
# 2552                  10.80                  14.53                   8.38
# 2553                  10.29                  17.14                   3.15
# 2554                  11.39                  16.61                   7.50
# 2555                   6.35                   9.15                   3.76
#
#       Relative Humidity [avg]  Dew Point [avg]  Dew Point [min]  ET0 [result]
# 2551                    99.86             10.3              8.8           NaN
# 2552                    99.86             10.6              8.2           NaN
# 2553                    92.94              8.8              3.0           3.4
# 2554                    90.32              9.4              5.2           3.0
# 2555                    99.86              6.2              3.6           NaN

# %%
plants_flightdate.shape
# Out:
# (3334, 11)

# %% [markdown]
# # Removin the empty entries for the plant date in plant data

# %%
plants_flightdate.dropna(subset=['Plant Date'],inplace=True)

# %%
plants_flightdate.shape
# Out:
# (3294, 11)

# %%
print("Number of null values in each column of plants data")
print(plants_flightdate.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                    0
# Batch Number             0
# Plant Date               0
# Class                    0
# Fresh Weight (g)         1
# Radial Diameter (mm)    98
# Polar Diameter (mm)     98
# Leaf Area (cm^2)         1
# Square ID                0
# Check Date               0
# Flight Date              0
# dtype: int64

# %% [markdown]
# # Removing empty entries for the fresh weight and leaf area in plant data

# %%
plants_flightdate.dropna(subset=['Fresh Weight (g)','Leaf Area (cm^2)'],inplace=True)

# %%
print("Number of null values in each column of plants data")
print(plants_flightdate.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                    0
# Batch Number             0
# Plant Date               0
# Class                    0
# Fresh Weight (g)         0
# Radial Diameter (mm)    97
# Polar Diameter (mm)     97
# Leaf Area (cm^2)         0
# Square ID                0
# Check Date               0
# Flight Date              0
# dtype: int64

# %%
plants_flightdate.shape
# Out:
# (3293, 11)

# %% [markdown]
# # Filling theradial diameter empty values in the plant data  in the column

# %%
plants_flightdate['Radial Diameter (mm)'] = plants_flightdate['Radial Diameter (mm)'].fillna(plants_flightdate['Radial Diameter (mm)'].mean())

# %%
print("Number of null values in each column of plants data")
print(plants_flightdate.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                    0
# Batch Number             0
# Plant Date               0
# Class                    0
# Fresh Weight (g)         0
# Radial Diameter (mm)     0
# Polar Diameter (mm)     97
# Leaf Area (cm^2)         0
# Square ID                0
# Check Date               0
# Flight Date              0
# dtype: int64

# %% [markdown]
# # Filling the empty values of the polar diameter

# %%
plants_flightdate['Polar Diameter (mm)'] = plants_flightdate['Polar Diameter (mm)'].fillna(plants_flightdate['Polar Diameter (mm)'].mean())

# %%
print("Number of null values in each column of plants data")
print(plants_flightdate.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                   0
# Batch Number            0
# Plant Date              0
# Class                   0
# Fresh Weight (g)        0
# Radial Diameter (mm)    0
# Polar Diameter (mm)     0
# Leaf Area (cm^2)        0
# Square ID               0
# Check Date              0
# Flight Date             0
# dtype: int64

# %%
plants_flightdate.shape
# Out:
# (3293, 11)

# %%
plants_flightdate.tail()
# Out:
#       index  Batch Number Plant Date  Class  Fresh Weight (g)  \
# 3309   3555           693 2020-08-08      1              81.0
# 3310   3556           693 2020-08-08      1             103.0
# 3311   3557           693 2020-08-08      3             132.0
# 3312   3558           693 2020-08-08      2             183.0
# 3313   3559           693 2020-08-08      3              98.0
#
#       Radial Diameter (mm)  Polar Diameter (mm)  Leaf Area (cm^2)  Square ID  \
# 3309                  36.0                 40.0             247.0        290
# 3310                  40.0                 50.0             211.0        290
# 3311                  40.0                 40.0             337.0        290
# 3312                  50.0                 45.0             370.0        290
# 3313                  30.0                 32.0             277.0        290
#
#      Check Date Flight Date
# 3309 2020-09-17  2020-09-10
# 3310 2020-09-17  2020-09-10
# 3311 2020-09-17  2020-09-10
# 3312 2020-09-17  2020-09-10
# 3313 2020-09-17  2020-09-10

# %% [markdown]
# # Counting days from the flight date and plant date in the plant data

# %%
plants_flightdate['days_to_check'] = plants_flightdate['Flight Date'] - plants_flightdate['Plant Date']

# %%
plants_flightdate.tail()
# Out:
#       index  Batch Number Plant Date  Class  Fresh Weight (g)  \
# 3309   3555           693 2020-08-08      1              81.0
# 3310   3556           693 2020-08-08      1             103.0
# 3311   3557           693 2020-08-08      3             132.0
# 3312   3558           693 2020-08-08      2             183.0
# 3313   3559           693 2020-08-08      3              98.0
#
#       Radial Diameter (mm)  Polar Diameter (mm)  Leaf Area (cm^2)  Square ID  \
# 3309                  36.0                 40.0             247.0        290
# 3310                  40.0                 50.0             211.0        290
# 3311                  40.0                 40.0             337.0        290
# 3312                  50.0                 45.0             370.0        290
# 3313                  30.0                 32.0             277.0        290
#
#      Check Date Flight Date days_to_check
# 3309 2020-09-17  2020-09-10       33 days
# 3310 2020-09-17  2020-09-10       33 days
# 3311 2020-09-17  2020-09-10       33 days
# 3312 2020-09-17  2020-09-10       33 days
# 3313 2020-09-17  2020-09-10       33 days

# %% [markdown]
# # To check the null values in the plant data

# %%
print("Number of null values in each column of plants data")
print(plants_flightdate.isnull().sum())
# Out:
# Number of null values in each column of plants data
# index                   0
# Batch Number            0
# Plant Date              0
# Class                   0
# Fresh Weight (g)        0
# Radial Diameter (mm)    0
# Polar Diameter (mm)     0
# Leaf Area (cm^2)        0
# Square ID               0
# Check Date              0
# Flight Date             0
# days_to_check           0
# dtype: int64
